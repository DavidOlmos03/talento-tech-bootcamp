# %%
# en el navegador de jupyter, abrir el notebook y ejecutar el siguiente código
# %pip install sqlalchemy

# %%
from sqlalchemy import create_engine,text
import pandas as pd
import sqlite3 as lite

engine = create_engine('sqlite:///../data/example_fts.db')

# connection to database
# conn = engine.connect('sqlite:///example_fts.db')

# consult 
def run_query(query:str):
    with engine.connect() as conn:
        # Check if the query is a modified query
        if query.strip().lower().startswith(('insert', 'update', 'delete','create')):
            # Execute queries as text
            conn.execute(text(query))
            # Commit the transaction
            conn.commit()
            return "Query executed successfully"
        else:
            res = conn.execute(text(query))
            result = pd.DataFrame(res.fetchall(),columns=res.keys())
            return result

# %%
# Crete query
create_table_query = """
    CREATE TABLE products (
        product_id INTEGER PRIMARY KEY,
        product_name TEXT,
        product_price INTEGER
    );
"""

create_table = run_query(create_table_query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# OperationalError: table products already exists
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 10
#       1 # Crete query
#       2 create_table_query = """
#       3     CREATE TABLE products (
#       4         product_id INTEGER PRIMARY KEY,
#    (...)
#       7     );
#       8 """
# ---> 10 create_table = run_query(create_table_query)
#
# Cell In[3], line 16, in run_query(query)
#      12 with engine.connect() as conn:
#      13     # Check if the query is a modified query
#      14     if query.strip().lower().startswith(('insert', 'update', 'delete','create')):
#      15         # Execute queries as text
# ---> 16         conn.execute(text(query))
#      17         # Commit the transaction
#      18         conn.commit()
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) table products already exists
# [SQL:
#     CREATE TABLE products (
#         product_id INTEGER PRIMARY KEY,
#         product_name TEXT,
#         product_price INTEGER
#     );
# ]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# Insert data 
insert_data_query = """
    INSERT INTO products (product_id, product_name, product_price) 
    VALUES 
                    (1, 'Portatil Acer 125', 3200000),
                    (2, 'Portatil Azus X28', 3499900),
                    (3, 'Portatil Acer 254', 1568742),
                    (4, 'Portatil HP L587', 2564789),
                    (5, 'MacBook 15PRO', 2500000),
                    (6, 'MacBook 16XT', 3859786),
                    (7, 'Impresora Canon 1245', 897520),
                    (8, 'Multifuncional Canon 1678', 1564230),
                    (9, 'Multifuncional Canon 4126', 2864250),
                    (10, 'Multifuncional Canon 1125', 1416000),
                    (11, 'PORTATIL ASUS VIVOBOOK X1504ZA NJ373', 8423700),
                    (12, 'GIGABYTE G6X 9KG 2024CORE i7', 5478222),
                    (13, 'LENOVO IP 3 14ALC6RYZ 3', 3584875),
                    (14, 'LENOVO IDEAPAD 1 15ALC7RYZ 5', 8423700),
                    (15, 'MSI THIN 15 B12UCX 2280XCO CORE i7', 12916210),
                    (16, 'ASUS VIVOBOOK', 5423700),
                    (17, 'HP14 DQ5016LACORE i5', 6918700),
                    (18, 'HP 15 DY5008LACORE i7', 3423700),
                    (19, 'MSI THIN 15 B12UCX 2280XCO CORE i7', 8228700),
                    (20, 'GIGABYTE G6X 9KG 2024 CORE i7', 4423700);
        
    """
run_query(insert_data_query)
# Out:
# 'Query executed successfully'

# %%
query = "SELECT * FROM products"
show_data = run_query(query)
show_data
# Out:
#     product_id                          product_name  product_price
# 0            1                     Portatil Acer 125        3200000
# 1            2                     Portatil Azus X28        3499900
# 2            3                     Portatil Acer 254        1568742
# 3            4                      Portatil HP L587        2564789
# 4            5                         MacBook 15PRO        2500000
# 5            6                          MacBook 16XT        3859786
# 6            7                  Impresora Canon 1245         897520
# 7            8             Multifuncional Canon 1678        1564230
# 8            9             Multifuncional Canon 4126        2864250
# 9           10             Multifuncional Canon 1125        1416000
# 10          11  PORTATIL ASUS VIVOBOOK X1504ZA NJ373        8423700
# 11          12          GIGABYTE G6X 9KG 2024CORE i7        5478222
# 12          13               LENOVO IP 3 14ALC6RYZ 3        3584875
# 13          14          LENOVO IDEAPAD 1 15ALC7RYZ 5        8423700
# 14          15    MSI THIN 15 B12UCX 2280XCO CORE i7       12916210
# 15          16                         ASUS VIVOBOOK        5423700
# 16          17                  HP14 DQ5016LACORE i5        6918700
# 17          18                 HP 15 DY5008LACORE i7        3423700
# 18          19    MSI THIN 15 B12UCX 2280XCO CORE i7        8228700
# 19          20         GIGABYTE G6X 9KG 2024 CORE i7        4423700

# %%
crete_catalog_query = """
    CREATE VIRTUAL TABLE catalog_products USING fts5(
        product_id,
        product_name,
        product_price
    )
"""

create_catalog = run_query(crete_catalog_query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# OperationalError: table catalog_products already exists
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[7], line 9
#       1 crete_catalog_query = """
#       2     CREATE VIRTUAL TABLE catalog_products USING fts5(
#       3         product_id,
#    (...)
#       6     )
#       7 """
# ----> 9 create_catalog = run_query(crete_catalog_query)
#
# Cell In[3], line 16, in run_query(query)
#      12 with engine.connect() as conn:
#      13     # Check if the query is a modified query
#      14     if query.strip().lower().startswith(('insert', 'update', 'delete','create')):
#      15         # Execute queries as text
# ---> 16         conn.execute(text(query))
#      17         # Commit the transaction
#      18         conn.commit()
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File ~/Documentos/projects/talento-tech/.venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) table catalog_products already exists
# [SQL:
#     CREATE VIRTUAL TABLE catalog_products USING fts5(
#         product_id,
#         product_name,
#         product_price
#     )
# ]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
insert_data_query_virtual_table = """
    INSERT INTO catalog_products(
        product_id,
        product_name,
        product_price
    ) SELECT product_id, product_name, product_price FROM products;
"""

insert_data_virtual = run_query(insert_data_query_virtual_table)

# %% [markdown]
# #### Show the virtual table

# %%
vista_query_virtual = "SELECT * FROM catalog_products"
vista_virtual = run_query(vista_query_virtual)
vista_virtual
# Out:
#     product_id                          product_name  product_price
# 0            1                       Laptop Acer 125            100
# 1            2                       Laptop Acer 135            200
# 2            3                     Laptop Lenovo 125            300
# 3            4                       Macbook Pro 145            400
# 4            5                     Impressora HP 155            500
# 5            6                         Laptop Dell 6            600
# 6            7                  Multifuncional Canon            700
# 7            8                          Printer HP 8            800
# 8            9                     Multifuncional HP            900
# 9           10                        Laptop Acer 10           1000
# 10           1                     Portatil Acer 125        3200000
# 11           2                     Portatil Azus X28        3499900
# 12           3                     Portatil Acer 254        1568742
# 13           4                      Portatil HP L587        2564789
# 14           5                         MacBook 15PRO        2500000
# 15           6                          MacBook 16XT        3859786
# 16           7                  Impresora Canon 1245         897520
# 17           8             Multifuncional Canon 1678        1564230
# 18           9             Multifuncional Canon 4126        2864250
# 19          10             Multifuncional Canon 1125        1416000
# 20          11  PORTATIL ASUS VIVOBOOK X1504ZA NJ373        8423700
# 21          12          GIGABYTE G6X 9KG 2024CORE i7        5478222
# 22          13               LENOVO IP 3 14ALC6RYZ 3        3584875
# 23          14          LENOVO IDEAPAD 1 15ALC7RYZ 5        8423700
# 24          15    MSI THIN 15 B12UCX 2280XCO CORE i7       12916210
# 25          16                         ASUS VIVOBOOK        5423700
# 26          17                  HP14 DQ5016LACORE i5        6918700
# 27          18                 HP 15 DY5008LACORE i7        3423700
# 28          19    MSI THIN 15 B12UCX 2280XCO CORE i7        8228700
# 29          20         GIGABYTE G6X 9KG 2024 CORE i7        4423700

# %% [markdown]
# #### Create the index

# %%
create_fts_index_query = """
                            SELECT 
                                t.product_id,
                                t.product_name,
                                t.product_price
                            FROM products AS t
                            INNER JOIN 
                                catalog_products AS c
                            ON 
                                c.product_id = t.product_id
                            WHERE 
                                catalog_products MATCH '15'
                            ORDER BY 
                                bm25(catalog_products,0,10);

                        """
create_fts_index = run_query(create_fts_index_query)
create_fts_index
# Out:
#    product_id                        product_name  product_price
# 0          18               HP 15 DY5008LACORE i7        3423700
# 1          15  MSI THIN 15 B12UCX 2280XCO CORE i7       12916210
# 2          19  MSI THIN 15 B12UCX 2280XCO CORE i7        8228700
